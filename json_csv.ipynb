# %%
import json

# %%
with open("data.json") as f:
    data = json.load(f)

# %%
data
# Out:
# [{'session_name': 'test',
#   'session_description': 'test',
#   'design_state_data': {'session_info': {'project_id': '1',
#     'experiment_id': 'kkkk-11',
#     'dataset': 'iris_modified.csv',
#     'session_name': 'test',
#     'session_description': 'test'},
#    'target': {'prediction_type': 'Regression',
#     'target': 'petal_width',
#     'type': 'regression',
#     'partitioning': True},
#    'train': {'policy': 'Split the dataset',
#     'time_variable': 'sepal_length',
#     'sampling_method': 'No sampling(whole data)',
#     'split': 'Randomly',
#     'k_fold': False,
#     'train_ratio': 0,
#     'random_seed': 0},
#    'metrics': {'optomize_model_hyperparameters_for': 'AUC',
#     'optimize_threshold_for': 'F1 Score',
#     'compute_lift_at': 0,
#     'cost_matrix_gain_for_true_prediction_true_result': 1,
#     'cost_matrix_gain_for_true_prediction_false_result': 0,
#     'cost_matrix_gain_for_false_prediction_true_result': 0,
# ...

# %%
for i in range(0, len(data)):
    print(data[i])
# Out:
# {'session_name': 'test', 'session_description': 'test', 'design_state_data': {'session_info': {'project_id': '1', 'experiment_id': 'kkkk-11', 'dataset': 'iris_modified.csv', 'session_name': 'test', 'session_description': 'test'}, 'target': {'prediction_type': 'Regression', 'target': 'petal_width', 'type': 'regression', 'partitioning': True}, 'train': {'policy': 'Split the dataset', 'time_variable': 'sepal_length', 'sampling_method': 'No sampling(whole data)', 'split': 'Randomly', 'k_fold': False, 'train_ratio': 0, 'random_seed': 0}, 'metrics': {'optomize_model_hyperparameters_for': 'AUC', 'optimize_threshold_for': 'F1 Score', 'compute_lift_at': 0, 'cost_matrix_gain_for_true_prediction_true_result': 1, 'cost_matrix_gain_for_true_prediction_false_result': 0, 'cost_matrix_gain_for_false_prediction_true_result': 0, 'cost_matrix_gain_for_false_prediction_false_result': 0}, 'feature_handling': {'sepal_length': {'feature_name': 'sepal_length', 'is_selected': True, 'feature_variable_type': '
# ...

# %%
import pandas as pd
df = pd.DataFrame(columns=["session_name", "session_description", "prediction_type", "target", "type", "partitioning", "policy", "time_variable", "sampling_method", "split", "k_fold", "train_ratio", "random_seed", "optomize_model_hyperparameters_for", "optimize_threshold_for", "compute_lift_at", "cost_matrix_gain_for_true_prediction_true_result", "cost_matrix_gain_for_true_prediction_false_result", "cost_matrix_gain_for_false_prediction_true_result", "cost_matrix_gain_for_false_prediction_false_result", "sepal_length_feature_name", "sepal_length_is_selected", "sepal_length_feature_variable_type", "sepal_length_numerical_handling", "sepal_length_rescaling", "sepal_length_make_derived_feats", "sepal_length_missing_values", "sepal_length_impute_with", "sepal_length_impute_value", "sepal_width_feature_name", "sepal_width_is_selected", "sepal_width_feature_variable_type", "sepal_width_numerical_handling", "sepal_width_rescaling", "sepal_width_make_derived_feats", "sepal_width_missing_values", "sepal_width_impute_with", "sepal_width_impute_value", "petal_length_feature_name", "petal_length_is_selected", "petal_length_feature_variable_type", "petal_length_numerical_handling", "petal_length_rescaling", "petal_length_make_derived_feats", "petal_length_missing_values", "petal_length_impute_with", "petal_length_impute_value", "petal_width_feature_name", "petal_width_is_selected", "petal_width_feature_variable_type", "petal_width"])

# %%
for i in range(0, len(data)):
    currentItems = data[i]

# %%
df.loc[i] = [data[i]["session_name"], [ "session_description"], [ "prediction_type"], [ "target"], [ "type"], [ "partitioning"], [ "policy"], [ "time_variable"], [ "sampling_method"], [ "split"], [ "k_fold"], [ "train_ratio"], [ "random_seed"], [ "optomize_model_hyperparameters_for"], [ "optimize_threshold_for"], [ "compute_lift_at"], [ "cost_matrix_gain_for_true_prediction_true_result"], [ "cost_matrix_gain_for_true_prediction_false_result"], [ "cost_matrix_gain_for_false_prediction_true_result"], [ "cost_matrix_gain_for_false_prediction_false_result"], [ "sepal_length_feature_name"], [ "sepal_length_is_selected"], [ "sepal_length_feature_variable_type"], [ "sepal_length_numerical_handling"], [ "sepal_length_rescaling"], [ "sepal_length_make_derived_feats"], [ "sepal_length_missing_values"], [ "sepal_length_impute_with"], [ "sepal_length_impute_value"], [ "sepal_width_feature_name"], [ "sepal_width_is_selected"], [ "sepal_width_feature_variable_type"], [ "sepal_width_numerical_handling"], [ "sepal_width_rescaling"], [ "sepal_width_make_derived_feats"], [ "sepal_width_missing_values"], [ "sepal_width_impute_with"], [ "sepal_width_impute_value"], [ "petal_length_feature_name"], [ "petal_length_is_selected"], [ "petal_length_feature_variable_type"], [ "petal_length_numerical_handling"], [ "petal_length_rescaling"], [ "petal_length_make_derived_feats"], [ "petal_length_missing_values"], [ "petal_length_impute_with"], [ "petal_length_impute_value"], [ "petal_width_feature_name"], [ "petal_width_is_selected"], [ "petal_width_feature_variable_type"], [ "petal_width"]]
            
#             ["session_name"], ["session_description"], ["prediction_type"], ["target"], ["type"], "partitioning", "policy", "time_variable", "sampling_method", "split", "k_fold", "train_ratio", "random_seed", "optomize_model_hyperparameters_for", "optimize_threshold_for", "compute_lift_at", "cost_matrix_gain_for_true_prediction_true_result", "cost_matrix_gain_for_true_prediction_false_result", "cost_matrix_gain_for_false_prediction_true_result", "cost_matrix_gain_for_false_prediction_false_result", "sepal_length_feature_name", "sepal_length_is_selected", "sepal_length_feature_variable_type", "sepal_length_numerical_handling", "sepal_length_rescaling", "sepal_length_make_derived_feats", "sepal_length_missing_values", "sepal_length_impute_with", "sepal_length_impute_value", "sepal_width_feature_name", "sepal_width_is_selected", "sepal_width_feature_variable_type", "sepal_width_numerical_handling", "sepal_width_rescaling", "sepal_width_make_derived_feats", "sepal_width_missing_values", "sepal_width_impute_with", "sepal_width_impute_value", "petal_length_feature_name", "petal_length_is_selected"], ["petal_length_feature_variable_type"], ["petal_length_numerical_handling"], ["petal_length_rescaling"], ["petal_length_make_derived_feats"], ["petal_length_missing_values"], ["petal_length_impute_with"], ["petal_length_impute_value"], ["petal_width_feature_name"], ["petal_width_is_selected"], ["petal_width_feature_variable_type"], ["petal_width"])

# %%
df
# Out:
#   session_name    session_description    prediction_type    target    type  \
# 0         test  [session_description]  [prediction_type]  [target]  [type]
#
#      partitioning    policy    time_variable    sampling_method    split  ...  \
# 0  [partitioning]  [policy]  [time_variable]  [sampling_method]  [split]  ...
#
#      petal_length_numerical_handling    petal_length_rescaling  \
# 0  [petal_length_numerical_handling]  [petal_length_rescaling]
#
#      petal_length_make_derived_feats    petal_length_missing_values  \
# 0  [petal_length_make_derived_feats]  [petal_length_missing_values]
#
#      petal_length_impute_with    petal_length_impute_value  \
# 0  [petal_length_impute_with]  [petal_length_impute_value]
#
#      petal_width_feature_name    petal_width_is_selected  \
# 0  [petal_width_feature_name]  [petal_width_is_selected]
#
#      petal_width_feature_variable_type    petal_width
# 0  [petal_width_feature_variable_type]  [petal_width]
#
# [1 rows x 51 columns]

# %%
df.head(10)
# Out:
#   session_name    session_description    prediction_type    target    type  \
# 0         test  [session_description]  [prediction_type]  [target]  [type]
#
#      partitioning    policy    time_variable    sampling_method    split  ...  \
# 0  [partitioning]  [policy]  [time_variable]  [sampling_method]  [split]  ...
#
#      petal_length_numerical_handling    petal_length_rescaling  \
# 0  [petal_length_numerical_handling]  [petal_length_rescaling]
#
#      petal_length_make_derived_feats    petal_length_missing_values  \
# 0  [petal_length_make_derived_feats]  [petal_length_missing_values]
#
#      petal_length_impute_with    petal_length_impute_value  \
# 0  [petal_length_impute_with]  [petal_length_impute_value]
#
#      petal_width_feature_name    petal_width_is_selected  \
# 0  [petal_width_feature_name]  [petal_width_is_selected]
#
#      petal_width_feature_variable_type    petal_width
# 0  [petal_width_feature_variable_type]  [petal_width]
#
# [1 rows x 51 columns]
